# %% [markdown]
# Ion Exchange Round 3 Group A1

# %% [markdown]
# <!--## List of Notation
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# @media screen and (max-width: 767px) {.tg {width: auto !important;}.tg col {width: auto !important;}.tg-wrap {overflow-x: auto;-webkit-overflow-scrolling: touch;}}</style>
# <div class="tg-wrap"><table class="tg">
#   <tr>
#     <th class="tg-c3ow">Symbol</th>
#     <th class="tg-c3ow">Unit</th>
#     <th class="tg-c3ow">Definition</th>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$C_F$</td>
#     <td class="tg-c3ow">$\dfrac{mol}{L}$</td>
#     <td class="tg-c3ow">Inlet concentration of copper sulfate</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$C$</td>
#     <td class="tg-c3ow">$\dfrac{\text{mol}}{\text{L}}$</td>
#     <td class="tg-c3ow">Effluent concentration of cupric sulfate at time t</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$t$</td>
#     <td class="tg-c3ow">min</td>
#     <td class="tg-c3ow">time</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$A$</td>
#     <td class="tg-c3ow">$AU$</td>
#     <td class="tg-c3ow">Absorbance in arbitrary units</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$m$</td>
#     <td class="tg-c3ow">$g$</td>
#     <td class="tg-c3ow">mass of resin</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$k_{Th}$</td>
#     <td class="tg-c3ow">---</td>
#     <td class="tg-c3ow">Thomas</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$q_F$</td>
#     <td class="tg-c3ow">---</td>
#     <td class="tg-c3ow">capacity</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">$Q$</td>
#     <td class="tg-c3ow">$\dfrac{\text{mol}}{\text{L}}$</td>
#     <td class="tg-c3ow">flow rate</td>
#   </tr>
# </table></div
# -->

# %% [markdown]
# # List of Notation
#
# **Table**: List of notation used in this document
#
# |      Symbol     |                      Unit                     |                     Definition                    |
# |:---------------:|:---------------------------------------------:|:-------------------------------------------------:|
# |      $C_F$      | $\dfrac{\text{mol}}{\text{L}}$                | Inlet concentration of copper sulfate             |
# |    $\text{C}$   | $\dfrac{\text{mol}}{\text{L}}$                | Effluent Concentration of copper sulfate          |
# |    $\text{t}$   | min                                           | time                                              |
# |        m        | g                                             | mass of resin                                     |
# | $\text{k}_{Th}$ | $\dfrac{\text{L}}{\text{mol}\cdot\text{min}}$ | Thomas rate constant                              |
# |   $q_{F_{I}}$   | $\dfrac{mol}{g\cdot \text{resin}}$            | resin capacity in ideal case, before regeneration |
# |   $q_{F_{R}}$   | $\dfrac{mol}{g\cdot \text{resin}}$            | resin capacity after regeneration                 |
# |      $Q_i$      | $\dfrac{\text{mL}}{\text{min}}$               | Flowrate when pump head is at label $i$           |
# |  $\varepsilon$  | $\dfrac{\text{L}}{\text{mol}}$                | extinction coefficient                            |

# %% [markdown]
# <!--
# # List of Notation
# \begin{table}
# \caption{My caption}
# \label{my-label}
# \begin{tabular}{|c|l|l|}
# \hline
# \textbf{Symbol} & \multicolumn{1}{c|}{\textbf{Unit}} & \multicolumn{1}{c|}{\textbf{Definition}} \\ \hline
# $C_F$ & $\dfrac{\text{mol}}{\text{L}}$ & Inlet concentration of copper sulfate \\ \hline
# $\text{C}$ & $\dfrac{\text{mol}}{\text{L}}$ & Effluent Concentration of copper sulfate \\ \hline
# $\text{t}$ & min & time \\ \hline
# m & g & mass of resin \\ \hline
# $\text{k}_{Th}$ & $\dfrac{\text{L}}{\text{mol}\cdot\text{min}}$ & Thomas rate constant \\ \hline
# $q_{F_{I}}$ & $\dfrac{mol}{g\cdot \text{resin}}$ & resin capacity in ideal case, before regeneration \\ \hline
# $q_{F_{R}}$ & $\dfrac{mol}{g\cdot \text{resin}}$ & resin capacity after regeneration \\ \hline
# $Q_i$ & $\dfrac{\text{mL}}{\text{min}}$ & Flowrate when pump head is at label $i$ \\ \hline
# $ε$ & $\dfrac{\text{L}}{\text{mol}}$ & extinction coefficient \\ \hline
# \end{tabular}
# \end{table}
# -->

# %% [markdown]
# # Relating flowrate to pump angle
# **Table**: Relating Pump head angle to flowrate
#
# |    Pump Head Angle | Flow Rate (ml/min) | Average Flow Rate (ml/min) |
# |:------------------:|:------------------:|:--------------------------:|
# |          3         | 8.11               | 8.03(+/- 0.11)             |
# |          3         | 7.95               |                            |
# |          6         | 14.43              | 14.31(+/-   0.17)          |

# %% [markdown]
# # Sample Calculations
# ## Sulfuric Acid Molarity Calculations
# Sulfuric Acid Concentration = $96.7\% w/w$
# Molar Mass = $98.08 \frac{g}{mol}$
# $ρ_{H_2SO_4} = 1.84 \frac{g}{mL}$   $ρ_{H_2O} = 1.0\frac{g}{mL}$
#
# $\left(96.7\frac{\text{g} H_2SO_4}{100g} \text{solution}\right) \times \left(1.84\frac{\text{g} H_2SO_4}{mL}\right) = 1.78\frac{\text{g}}{\text{mL}} \text{solution}\times \left(1000\frac{\text{mL}}{\text{L}}\right) \times \left(\frac{1\text{mol} H_2SO+4}{98.08\text{g}}\right) = 18.1 \frac{\text{mol}}{\text{L}}  = 18.1 \text{M}$
#
# ### Diluting to Desired Molarity
# $M_1V_1 = M_2V_2$
# Desired Molarity = $0.4 M$
# Desired Volume = $0.25L$
# $H_2SO_4$ to add = $\dfrac{0.4M * 0.25 L}{18.1 M} \times \dfrac{1000 mL}{1 L}$ = 5.52 mL $H_2SO_4$
# Remaining water = 250mL - 5.52 mL = 244.48 mL
#
# ## Calculation of Concentration from Absorbance
# Beer Lambert’s Law
# $A = ε c l$
# Here $ε = 3.34 \frac{\text{mol}}{\text{L}}\times \text{cm}$ (average taken from previous groups),  $l = 1\text{cm}$,
#  c = $A\frac{\left(xxxx\right)}{3.34 \times 1}$
#
# ## Thomas Model
# $ln\left(\dfrac{C_F}{C}-1\right) = \dfrac{k_{Th}\;q_F\;m}{Q} - k_{Th} C_F t$
#
# To determine $k_{Th}$ in these calcultaions, plot $ln\left(\dfrac{C_F}{C}-1\right)$ vs time.  The slope is equal to $-k_{Th}\cdot C_F$
# Therefore, it follows that $k_{Th} = \dfrac{-\text{slope}}{C_F}$
#
# $q_F$ is determined from the y-intercept of the same plot. The y intercept is equal to $\dfrac{k_{Th}\cdot q_F \cdot m}{Q}$
#
# Therefore, $q_F = \dfrac{\text{y-intercept}\cdot Q}{m \cdot k_{Th}}$

# %% [markdown]
# # Analysis of Day 1
# Please note that no viable data was collected on day 1 because day 1 was dedicated to learning the instrumentation, and the group had problems figuring out how to correctly retrieve data from the spectrophotometer, and did not know the proper protocols for setting a blank. Additionally, it took over 2 hours to pack the column on Day 1, because of inexperience. All of these problems were solved by day 2.
#
# # Analysis of Day 2
# ## Plotting concentration time information
# This follows the process for doing the analysis of the data collected on day one. All variables end with 3, such as in `Variable3` to denote that the flowrated was determined by putting the pump to setting #3. Variables that do not have a number appended and are not otherwise noted, are constant through all flowrate settings.
#
# ### Setting up code
# First, useful packages are imported. Pandas reads text files into table data, numpy is a numerical calculator, and matplotlib is a plotting package.
#
# import pandas as pd
# import matplotlib
# from matplotlib import pyplot as plt
# import numpy as np

# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Defining Constants
#
# #### Copper (II) Sulfate Concentration
# Inlet concentration of Copper Sulfate in molar
#
#
# **Please note:** _This value does not change when the flowrates change and will not be redifined later_

# %%
CF = 0.5 # Molar

# %% [markdown]
# #### Averaging the calibration values from all previous  groups
# `eps` refers to $ε$, the extinction coefficient from Beer's law
# We did not create a new calibration due to time constraints, so the value used is an arethemetic mean of the values used in all previous reports(1-12).
#
# **Please note:** _This value does not change and will not be redefined later_

# %%
eps = np.mean(np.array([3.4831, 3.347, 3.0928,3.3949, 3.2215, 3.41950, 3.3562,3.2809,3.41,3.4086, 3.4157]))
epsstd = np.std(np.array([3.4831, 3.347, 3.0928,3.3949, 3.2215, 3.41950, 3.3562,3.2809,3.41,3.4086, 3.4157]))

ul = round((eps + 3*epsstd),3)
ll = round((eps - 3*epsstd),3)

print(epsstd, ul, ll)
# Out:
# 0.10590004721434265 3.666 3.03

# %% [markdown]
# The mean of data from previous groups is a reasonable value because the $\bar{ε} = 3.348$, with a standard deviation, $σ = 0.1059$ has lower and upper limits (defined as $ε \pm 3σ$,) of $3.03$ and $3.666$, respectively

# %% [markdown]
# #### Recording Flowrate for angle 3
# There were two flowrate measurements made for each pump angle. `Q3`, or the measured flowrate for angle 3, is the average of two values, $\dfrac{20 mL}{151 s}$ an $\dfrac{20 mL}{148 s}$ reported in $\dfrac{mL}{min}$

# %%
Q3 = np.mean([(20/151),(20/148)])*60
print("Q3 = {} mL/min".format(round(Q3,3)))
# Out:
# Q3 = 8.028 mL/min

# %% [markdown]
# #### `m3` is Mass of resin on Day2, where the flowrate was at angle 3
# Below is the mass of resin in grams put into the column on day 2.

# %%
m3 = 2.540

# %% [markdown]
# ### Importing raw data, then defining data variables
#
# The naming convention `r#d#f#*` where the `#` refers to a numerical value and `*` refers to a letter value
#
# So, for example:
#
# `r1d2f3a` refers to the text file named `Run1_FR_3_A.txt`, which occured on lab experiment day 2, was the first run, had a flowrate of 3 and was part a
#
# This process is simply repeated for each data file

# %%
r1d2f3a = pd.read_csv('01_Text_Files/Run1_FR_3_A.txt',skiprows=7,header=None,sep='\t')
r1d2f3a.columns = ["time","Transmittance","Absorbance"]
r1d2f3a['time_Plot'] = r1d2f3a.time
r1d2f3a['time'] = r1d2f3a.time
r1d2f3a['time_s'] = r1d2f3a.time*60


r1d2f3b = pd.read_csv('01_Text_Files/Run1_FR_3_B.txt',skiprows=7,header=None,sep='\t')
r1d2f3b.columns = ["time","Transmittance","Absorbance"]
r1d2f3a_timearray = np.array(r1d2f3a.time_Plot)
r1d2f3b['time_Plot'] = r1d2f3a_timearray[-1] + r1d2f3b.time
r1d2f3b['time_s'] = r1d2f3b.time*60

r1d2f3c = pd.read_csv('01_Text_Files/Run1_FR_3_C.txt',skiprows=7,header=None,sep='\t')
r1d2f3c.columns = ["time","Transmittance","Absorbance"]
r1d2f3b_timearray = np.array(r1d2f3b.time_Plot)
r1d2f3c['time_Plot'] = r1d2f3b_timearray[-1] + r1d2f3c.time
r1d2f3b['time_s'] = r1d2f3b.time*60


r2d2f3a = pd.read_csv('01_Text_Files/Run2_FR_3_A.txt',skiprows=7,header=None,sep='\t')
r2d2f3a.columns = ["time","Transmittance","Absorbance"]
r1d2f3c_timearray = np.array(r1d2f3c.time_Plot)
r2d2f3a['time_Plot'] = r1d2f3c_timearray[-1] + r2d2f3a.time
r2d2f3a['time_s'] = r2d2f3a.time*60

# %% [markdown]
# ### Calculating concentration
# Concentration is calculated from the absorbance data, by dividing the absorbance value by the extinction coefficient of copper(II)sulfate in water

# %%
r1d2f3a['Concentration'] = r1d2f3a.Absorbance/eps
r1d2f3b['Concentration'] = r1d2f3b.Absorbance/eps
r1d2f3c['Concentration'] = r1d2f3c.Absorbance/eps
r2d2f3a['Concentration'] = r2d2f3a.Absorbance/eps

# %% [markdown]
# ### Plotting Breakthrough Curve
# The following plot is actually showinig three breakthrough and two regeneration curves.

# %%
ax = r1d2f3a.plot(x='time_Plot',y='Concentration',label='Before Regeneration')
r1d2f3b.plot(x='time_Plot',y='Concentration',ax=ax,label='Regeneration 1',color='C0',legend=False)
r1d2f3c.plot(x='time_Plot',y='Concentration',ax=ax, color = 'C1',label='After Regeneration')
r2d2f3a.plot(x='time_Plot',y='Concentration',ax=ax,label='Run 2 & 3', legend=False)
ax.set_xlabel('time (min)')
ax.set_ylabel('Concentration Copper Sulfate ($\dfrac{mol}{L}$)')
title3 = "Concentration vs Time Plot for Q = {} mL/min".format(round(Q3,3))
ax.set_title(title3)
# Out:
# Text(0.5,1,'Concentration vs Time Plot for Q = 8.028 mL/min')

# %% [markdown]
# #### Defining and Plotting the Thomas Model over the entire breakthru curve
# I am interested in seein the entire thomas model. Additionally, this plot is in seconds, and not minutes.

# %%
r1d2f3a['Thomas'] = np.log((CF/r1d2f3a.Concentration)-1)
r2d2f3a['Thomas'] = np.log((CF/r1d2f3a.Concentration)-1)
ax1 = r1d2f3a.plot(x='time_s',y='Concentration',label='Before Regen')
r2d2f3a.plot(x='time_s',y='Concentration',label='After Regen',ax=ax1)
ax2 = r1d2f3a.plot(x='time_s',y='Thomas',label='Before Regen')
r2d2f3a.plot(x='time_s',y='Thomas',label='After Regen',ax=ax2)

r1d2f3a_sub = r1d2f3a[(r1d2f3a.Thomas>0) &(r1d2f3a.Transmittance<100)& (r1d2f3a.time_s < 500)].copy()
r2d2f3a_sub = r2d2f3a[(r2d2f3a.Thomas>0) &(r2d2f3a.Transmittance<100)& (r2d2f3a.time_s < 500)].copy()
ax3 = r1d2f3a_sub.plot.scatter(x='time_s',y='Thomas',label='Before Regen',c='C0')
r2d2f3a_sub.plot.scatter(x='time_s',y='Thomas',label='After Regen',ax=ax3,c='C1')

import scipy as sc
from scipy import stats

#slopeI, interceptI, r_valueI, p_valueI, std_errI = stats.linregress(r2d2f3a_sub['time_s'],r2d2f3a_sub['Thomas'])
#slopeR, interceptR, r_valueR, p_valueR, std_errR = stats.linregress(r2d2f3a_sub['time_s'],r2d2f3a_sub['Thomas'])
#r1d2f3a_sub['ThomasPredict'] = slopeI*r1d2f3a_sub['time_s'] + interceptI
#r1d2f3a_sub['ThomasPredict'] = slopeR*r2d2f3a_sub['time_s'] + interceptR

#r1d2f3a_sub.plot(x='time_s',y='ThomasPredict',ax=ax3,label='Before Regen')
#r2d2f3a_sub.plot(x='time_s',y='ThomasPredict',ax=ax3,label='After Regen')

#kthI = -slopeI/CF
#qFI = (interceptI*Q3)/(m3*kthI)

# %% [markdown]
# #### Comparing the breakthrough curve from b efore and after regeneration
# `ideal3` and `regen1_3` are copies of the data above, defined just for the part of the "begining" part of the breakthrough curve.
# The plot shows the section of the breakthrough that the Thomas Model analysis will be done on.
# Please note, due to ease of analysis, the third breakthrough curve shown above is not used in the analysis below.

# %%
ideal3 = r1d2f3a[(r1d2f3a.time < 2.75) & (r1d2f3a.time>=1.5)&(r1d2f3a.Transmittance<100)].copy()
ax = ideal3.plot(x='time',y='Concentration',label='Before Regeneration')
regen1_3 = r2d2f3a[(r2d2f3a.time <= 2.5) & (r2d2f3a.time>= 1.25) & (r2d2f3a.Transmittance<100)].copy()
regen1_3.plot(x='time',y='Concentration',label='After Regeneration',ax=ax)
ax.set_ylabel('Concentration ($\dfrac{mol}{L}$)')
title3 = "Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = {} mL/min".format(round(Q3,3))
ax.set_title(title3)
# Out:
# Text(0.5,1,'Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = 8.028 mL/min')

# %% [markdown]
# _Note: Call ideal 3 maybe?_

# %% [markdown]
# ## Plotting the thomas model plot before and after regeneration

# %%
ideal3['Thomas'] = np.log((CF/ideal3['Concentration'])-1)
regen1_3['Thomas'] = np.log((CF/regen1_3['Concentration'])-1)
ax = ideal3.plot.scatter(x='time_s',y='Thomas',label='Breakthrough 1',color='C0')
regen1_3.plot.scatter(x='time_s',y='Thomas',label='After Regeneration 1',ax=ax,color='C1')
ax.set_xlabel('time(min)')
ax.set_ylabel('$ln(\dfrac{C_F}{C} -1)$')

title3 = "Thomas Model Curve Comparing before and After \n regeneration at Flowrate = {} mL/min".format(round(Q3,3))
ax.set_title(title3)

import scipy as sc
from scipy import stats

slopeI3, interceptI3, r_valueI3, p_valueI3, std_errI3 = stats.linregress(ideal3['time_s'],ideal3['Thomas'])
slopeR3, interceptR3, r_valueR3, p_valueR3, std_errR3 = stats.linregress(regen1_3['time_s'],regen1_3['Thomas'])
ideal3['ThomasPredict'] = ideal3['time_s']*slopeI3 + interceptI3
regen1_3['ThomasPredict'] = regen1_3['time_s']*slopeR3 + interceptR3
ideal3.plot(x='time_s',y='ThomasPredict', ax=ax,label='Ideal',color='C0')
regen1_3.plot(x='time_s',y='ThomasPredict', ax=ax,label='Regenerated',color='C1')

print([[slopeI3, interceptI3, (r_valueI3**2),p_valueI3,std_errI3],[slopeR3, interceptR3, (r_valueR3**2),p_valueR3,std_errR3]])
# Out:
# [[-0.13761676521486352, 18.544524878775512, 0.9664700802747417, 7.844021980074007e-55, 0.003020835990955253], [-0.09793958542377244, 12.652586826197286, 0.9886975708769342, 1.1472152328086925e-35, 0.001770020929658709]]

# %% [markdown]
# ### Reporting slope and intercept for Thomas Model at FR3

# %%
print("For Ideal Case: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(slopeI3, interceptI3,r_valueI3**2))
print("After 1 regeneration: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(slopeR3, interceptR3,r_valueR3**2))
# Out:
# For Ideal Case:
# Slope = -0.13761676521486352
#  y- intercept = 18.544524878775512
#  R^2 value = 0.9664700802747417
# After 1 regeneration:
# Slope = -0.09793958542377244
#  y- intercept = 12.652586826197286
#  R^2 value = 0.9886975708769342

# %% [markdown]
# #### Reporting Thomas Model Flowrtate = {{Q3}} $\dfrac{mL}{min}$

# %% [markdown]
# ### Calculating $q_F$ and $k_{Th}$ from Thomas model
# Below calculates the Thomas Model parameters, $q_F$ and $k_{Th}$, from the calculated slope and intercept, and measured values, such as the flowrate, and mass of resin.

# %%
kthI3 = -slopeI3/CF
qFI3 = (interceptI3 * Q3)/(m3 * kthI3)

print(m3)

kthR3 = -slopeR3/CF
qFR3 = (interceptR3 * Q3)/(m3 * kthR3)

print("Flowrate = {} mL/min \n Ideal case \n \tkth: {} \n\tqF: {}".format(round(Q3,3),round(kthI3,3), round(qFI3,3)))
print("After 1 regeneration\n \tkth: {} \n\tqF: {}".format(round(kthR3,3), round(qFR3,3)))
print("Efficiency = {}".format(round((qFR3*100/qFI3),3)))
# Out:
# 2.54
# Flowrate = 8.028 mL/min
#  Ideal case
#  	kth: 0.275
# 	qF: 212.944
# After 1 regeneration
#  	kth: 0.196
# 	qF: 204.146
# Efficiency = 95.869

# %% [markdown]
# # Analysis of Data Collected on Day 3
# ## Recording Constants
# ### Mass of Resin Used
# Below, is the mass of resin packed into the column in grams.
# `m9` refers to the mass used when the flowrate was at label #9 and `m6` refers to the mass used when the flowrate was at label #6

# %%
m6 = 2.332
m9 = 2.304

# %% [markdown]
# ### Volumetric Flowrates
# `Q9` and `Q6` refer to the volumetric flowrates when the pump was set to angles 9 and 6 respectively.
# $Q_9$ was recorded to have flowrates of $\dfrac{10 mL}{28.27 s}$ and $\dfrac{10 mL}{28.26 s}$
# $Q_6$ was recorded to have flowrates of $\dfrac{10 mL}{42.29 s}$ and $\dfrac{10 mL}{41.57}$
# Both $Q_9$ and $Q_6$ are reported in $\dfrac{\text{mL}}{\text{min}}$

# %%
Q9 = np.mean([(10/28.27),(10/28.26)])*60
Q6 = np.mean([(10/42.29),(10/41.57)])*60

# %% [markdown]
# ## Importing Raw Data
# The method used to decide on variable names is exactly the same as the one used for the previous experimental day

# %%
r3d3f9a = pd.read_csv('01_Text_Files/Run3_FR_9_A.txt',skiprows=7,header=None,sep='\t')
r3d3f9a.columns = ["time","Transmittance","Absorbance"]
r3d3f9a['time_Plot'] = r3d3f9a.time
r3d3f9a_timearray = np.array(r3d3f9a.time_Plot)

r3d3f9b = pd.read_csv('01_Text_Files/Run3_FR_9_B.txt',skiprows=7,header=None,sep='\t')
r3d3f9b.columns = ["time","Transmittance","Absorbance"]
r3d3f9b['time_Plot'] = r3d3f9a_timearray[-1] + r3d3f9b.time
r3d3f9b_timearray = np.array(r3d3f9b.time_Plot)

r4d3f6a = pd.read_csv('01_Text_Files/Run4_FR_6_A.txt',skiprows=7,header=None,sep='\t')
r4d3f6a.columns = ["time","Transmittance","Absorbance"]
r4d3f6a['time_Plot'] = r4d3f6a.time
r4d3f6a_timearray = np.array(r4d3f6a.time_Plot)

r4d3f6b = pd.read_csv('01_Text_Files/Run4_FR_6_B.txt',skiprows=7,header=None,sep='\t')
r4d3f6b.columns = ["time","Transmittance","Absorbance"]
r4d3f6b['time_Plot'] = r4d3f6a_timearray[-1] + r4d3f6b.time
r4d3f6b_timearray = np.array(r4d3f6b.time_Plot)

# %% [markdown]
# ## Calculating concentration from Absorbance

# %%
r3d3f9a['Concentration'] = r3d3f9a.Absorbance/eps
r3d3f9b['Concentration'] = r3d3f9b.Absorbance/eps
r4d3f6a['Concentration'] = r4d3f6a.Absorbance/eps
r4d3f6b['Concentration'] = r4d3f6b.Absorbance/eps

# %% [markdown]
# ## Plotting Breakthrough Curves Sequentially
# This is plotting Concentration vs Time
# The breakthrough curves are the part of the curve that increase, have a constant section and then decrease.
# The regeneration curve is the the part where $H_2SO_4$ was washed through the system. It has a sharp peak, and follows the breakthrough curve. The cycle labeled "Before Regeneration" means that it starts with fresh resin.

# %%
ax = r3d3f9a.plot(x='time_Plot',y='Concentration',label='Before Regeneration')
r3d3f9b.plot(x='time_Plot',y='Concentration',ax=ax,label='After Regeneration')
ax.set_xlabel('time (min)')
ax.set_ylabel('Concentration Copper Sulfate ($\dfrac{mol}{L}$)')
title9 = "Concentration vs Time plot for Q = {} mL/m".format(round(Q9,3))
ax.set_title(title9)

ax2 = r4d3f6a.plot(x='time_Plot',y='Concentration',label='Before Regeneration')
r4d3f6b.plot(x='time_Plot',y='Concentration',ax=ax2,label='After Regeneration')
ax2.set_ylabel('Concentration Copper Sulfate ($\dfrac{mol}{L}$)')
title6 = "Concentration vs Time plot for Q = {} mL/m".format(round(Q6,3))
ax2.set_title(title6)
# Out:
# Text(0.5,1,'Concentration vs Time plot for Q = 14.311 mL/m')

# %% [markdown]
# ## Thomas Model
# ### Comparing breakthrough curves before and after a regeneration cycle.
# Please note that this region is determined manually. This will be the part of the breakthrough curves that will be analyzed looking at the Thomas model. This is because the Thomas model is only valid in the monatonically increasing section of the breakthrough curve.

# %%
ideal9 = r3d3f9a[(r3d3f9a.time <= 1) & (r3d3f9a.time>=0.8)].copy()
ax = ideal9.plot(x='time',y='Concentration',label='Before Regeneration')
regen1_9 = r3d3f9b[(r3d3f9b.time<= 0.9) & (r3d3f9b.time>=0.7)].copy()
regen1_9.plot(x='time',y='Concentration',label='After Regeneration',ax=ax)
ax.set_ylabel('Concentration ($\dfrac{mol}{L}$)')
title9 = "Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = {} mL/min".format(round(Q9,3))
ax.set_title(title9)

ideal6 = r4d3f6a[(r4d3f6a.time <= 1.3) & (r4d3f6a.time>=1.1)].copy()
ax2 = ideal6.plot(x='time',y='Concentration',label='Before Regeneration')
regen1_6 = r4d3f6b[(r4d3f6b.time<= 1.3) & (r4d3f6b.time>=1.1)].copy()
regen1_6.plot(x='time',y='Concentration',label='After Regeneration',ax=ax2)
ax2.set_ylabel('Concentration ($\dfrac{mol}{L}$)')
title6 = "Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = {} mL/min".format(round(Q6,3))
ax2.set_title(title6)
# Out:
# Text(0.5,1,'Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = 14.311 mL/min')

# %% [markdown]
# ### Calculating and Plotting the Thomas Model

# %%
# Calculating and Plotting Thomas Model Points
ideal9['Thomas'] = np.log((CF/ideal9['Concentration'])-1)
regen1_9['Thomas'] = np.log((CF/regen1_9['Concentration'])-1)
ax = ideal9.plot.scatter(x='time',y='Thomas',label='Breakthrough 1',color='C0')
regen1_9.plot.scatter(x='time',y='Thomas',label='After Regeneration 1',ax=ax,color='C1')
ax.set_xlabel('time(min)')
ax.set_ylabel('$ln(\dfrac{C_F}{C} -1)$')
title9 = "Thomas Model Curve Comparing before and After \n regeneration at Flowrate = {} mL/min".format(round(Q9,3))
ax.set_title(title9)

ideal6['Thomas'] = np.log((CF/ideal6['Concentration'])-1)
regen1_6['Thomas'] = np.log((CF/regen1_6['Concentration'])-1)
ax2 = ideal6.plot.scatter(x='time',y='Thomas',label='Breakthrough 1',color='C0')
regen1_6.plot.scatter(x='time',y='Thomas',label='After Regeneration 1',ax=ax2,color='C1')
ax2.set_xlabel('time(min)')
ax2.set_ylabel('$ln(\dfrac{C_F}{C} -1)$')
title6 = "Thomas Model Curve Comparing before and After \n regeneration at Flowrate = {} mL/min".format(round(Q6,3))
ax2.set_title(title6)

# Calcualting the linear fit of the thomas model, and plotting it with the calculated Thomas model points.
slopeI9, interceptI9, r_valueI9, p_valueI9, std_errI9 = stats.linregress(ideal9['time'],ideal9['Thomas'])
slopeR9, interceptR9, r_valueR9, p_valueR9, std_errR9 = stats.linregress(regen1_9['time'],regen1_9['Thomas'])
ideal9['ThomasPredict'] = ideal9['time']*slopeI9 + interceptI9
regen1_9['ThomasPredict'] = regen1_9['time']*slopeR9 + interceptR9
ideal9.plot(x='time',y='ThomasPredict', ax=ax,label='Ideal',color='C0')
regen1_9.plot(x='time',y='ThomasPredict', ax=ax,label='Regenerated',color='C1')


slopeI6, interceptI6, r_valueI6, p_valueI6, std_errI6 = stats.linregress(ideal6['time'],ideal6['Thomas'])
slopeR6, interceptR6, r_valueR6, p_valueR6, std_errR6 = stats.linregress(regen1_6['time'],regen1_6['Thomas'])
ideal6['ThomasPredict'] = ideal6['time']*slopeI6 + interceptI6
regen1_6['ThomasPredict'] = regen1_6['time']*slopeR6 + interceptR6
ideal6.plot(x='time',y='ThomasPredict', ax=ax2,label='Ideal',color='C0')
regen1_6.plot(x='time',y='ThomasPredict', ax=ax2,label='Regenerated',color='C1')

# %% [markdown]
# #### Reporting slope and intercept for Thomas Model

# %%
print("For Flowrate Q = {} mL/min".format(round(Q3,3)))
print("For Ideal Case: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(round(slopeI3,3), round(interceptI3,3),round(r_valueI3**2,3)))
print("After 1 regeneration: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(round(slopeR3,3), round(interceptR3,3),round(r_valueR3**2,3)))
print('\n')
print("For Flowrate Q = {} mL/min".format(round(Q9,3)))
print("For Ideal Case: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(round(slopeI9,3), round(interceptI9,3),round(r_valueI9**2,3)))
print("After 1 regeneration: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(round(slopeR9,3), round(interceptR9,3),round(r_valueR9**2,3)))
print('\n')
print("For Flowrate Q = {} mL/min".format(round(Q6,3)))
print("For Ideal Case: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(round(slopeI6,3), round(interceptI6,3),round(r_valueI6**2,3)))
print("After 1 regeneration: \nSlope = {}\n y- intercept = {} \n R^2 value = {}".format(round(slopeR6,3), round(interceptR6,3),round(r_valueR6**2,3)))
# Out:
# For Flowrate Q = 8.028 mL/min
# For Ideal Case:
# Slope = -0.138
#  y- intercept = 18.545
#  R^2 value = 0.966
# After 1 regeneration:
# Slope = -0.098
#  y- intercept = 12.653
#  R^2 value = 0.989
#
#
# For Flowrate Q = 21.228 mL/min
# For Ideal Case:
# Slope = -22.19
#  y- intercept = 20.043
#  R^2 value = 0.991
# After 1 regeneration:
# Slope = -23.092
#  y- intercept = 17.887
#  R^2 value = 0.998
#
#
# For Flowrate Q = 14.311 mL/min
# For Ideal Case:
# Slope = -20.417
#  y- intercept = 24.298
#  R^2 value = 0.999
# After 1 regeneration:
# Slope = -20.77
#  y- intercept = 24.894
#  R^2 value = 0.998

# %% [markdown]
# <!--
# #### Reporting Thomas Model results
# -->
#
# <!--|Flowrate ($\dfrac{mL}{min}$)|Case|slope|intercept|$R^2$|p-value|
# |---|---|---|---|---|---|
# |{{round(Q3,3)}}|Ideal|{{round(slopeI3,3)}}|{{round(interceptI3,3)}}|{{round(r_valueI3**2,3)}}|{{p_valueI3,3}}|
# |{{round(Q3,3)}}|Regen|{{round(slopeR3,3)}}|{{round(interceptR3,3)}}|{{round(r_valueR3**2,3)}}|{{p_valueR3,3}}|
# |{{round(Q6,3)}}|Ideal|{{round(slopeI6,3)}}|{{round(interceptI6,3)}}|{{round(r_valueI6**2,3)}}|{{p_valueI6,3}}|
# |{{round(Q6,3)}}|Regen|{{round(slopeR6,3)}}|{{round(interceptR6,3)}}|{{round(r_valueR6**2,3)}}|{{p_valueR6}}|
# |{{round(Q9,3)}}|Ideal|{{round(slopeI9,3)}}|{{round(interceptI9,3)}}|{{round(r_valueI9**2,3)}}|{{p_valueI9}}|
# |{{round(Q9,3)}}|Regen|{{round(slopeR9,3)}}|{{round(interceptR9,3)}}|{{round(r_valueR9**2,3)}}|{{p_valueR9}}|
# -->

# %% [markdown]
# #### Reporting Thomas Model Results
#
# |Flowrate ($\dfrac{mL}{min}$)|Case|slope|intercept|$R^2$|p-value|
# |---|---|---|---|---|---|
# | 8.028|Ideal| -0.138|18.545|0.966|$7.844 \times 10^{-55}$|
# | 8.028|Regen| -0.098|12.653|0.989|$1.147 \times 10^{-35}$|
# |14.311|Ideal|-20.417|24.298|0.999|$1.000 \times 10^{-32}$|
# |14.311|Regen|-20.770|24.894|0.998|$2.370 \times 10^{-31}$|
# |21.228|Ideal|-22.190|20.043|0.991|$6.085 \times 10^{-25}$|
# |21.228|Regen|-23.092|17.887|0.998|$1.870 \times 10^{-32}$|

# %% [markdown]
# ### Calculating $q_F$ and $k_{Th}$ from Thomas model
# Below calculates the Thomas Model parameters, $q_F (\dfrac{mol}{g\cdot\text{resin}})$ and $k_{Th}$, from the calculated slope and intercept, and measured values, such as the flowrate, and mass of resin.

# %%
kthI3 = -slopeI3/CF
qFI3 = (interceptI3 * Q3)/(m3 * kthI3)
kthR3 = -slopeR3/CF
qFR3 = (interceptR3 * Q3)/(m3 * kthR3)

kthI9 = -slopeI9/CF
qFI9 = (interceptI9 * Q9)/(m9 * kthI9)
kthR9 = -slopeR9/CF
qFR9 = (interceptR9 * Q9)/(m9 * kthR9)

regenEff9 = (qFR9/qFI9)*100

kthI6 = -slopeI6/CF
qFI6 = (interceptI6 * Q6)/(m6 * kthI6)
kthR6 = -slopeR6/CF
qFR6 = (interceptR6 * Q6)/(m6 * kthR6)

regenEff6 = (qFR6/qFI6)*100

regenEff3 = (qFR3/qFI3)*100

print("Flowrate = {} mL/min \n Ideal case \n \tkth: {} \n\tqF: {}".format(round(Q3,3),round(kthI3,3), round(qFI3,3)))
print(" After 1 regeneration\n \tkth: {} \n\tqF: {} mol/g resin".format(round(kthR3,3), round(qFR3,3)))
print("Regeneration Efficiency = {}\n\n".format(round(regenEff3,3)))

print("Flowrate = {} mL/min \n Ideal case \n \tkth: {} \n\tqF: {}".format(round(Q6,3),round(kthI6,3), round(qFI6,3)))
print(" After 1 regeneration\n \tkth: {} \n\tqF: {} mol/g resin".format(round(kthR6,3), round(qFR6,3)))
print("Regeneration Efficiency = {}\n\n".format(round(regenEff6,3)))

print("Flowrate = {} mL/min \n Ideal case \n \tkth: {} \n\tqF: {}".format(round(Q9,3),round(kthI9,3), round(qFI9,3)))
print(" After 1 regeneration\n \tkth: {} \n\tqF: {} mol /g resin".format(round(kthR9,3), round(qFR9,3)))
print("Regeneration Efficiency = {}\n\n".format(round(regenEff9,3)))
# Out:
# Flowrate = 8.028 mL/min
#  Ideal case
#  	kth: 0.275
# 	qF: 212.944
#  After 1 regeneration
#  	kth: 0.196
# 	qF: 204.146 mol/g resin
# Regeneration Efficiency = 95.869
#
#
# Flowrate = 14.311 mL/min
#  Ideal case
#  	kth: 40.834
# 	qF: 3.652
#  After 1 regeneration
#  	kth: 41.54
# 	qF: 3.678 mol/g resin
# Regeneration Efficiency = 100.712
#
#
# Flowrate = 21.228 mL/min
#  Ideal case
#  	kth: 44.38
# 	qF: 4.161
#  After 1 regeneration
#  	kth: 46.183
# 	qF: 3.568 mol /g resin
# Regeneration Efficiency = 85.76

# %% [markdown]
# <!--
# # Results -->
#
# <!--|Flowrate $\dfrac{mL}{min}$|Mass of resin used (g)|Real Capacity $q_{F_R}$|Ideal Capacity $q_{F_I}$|Regeneration Effeciency (%)|
# |---|---|---|---|---|
# |{{round(Q3_2,3)}}|{{round(m3_2,3)}}|{{round(qFR3_2,3)}}|{{round(qFI3_2)}}|{{round(regenEff3_2,3)}}
# |{{round(Q3,3)}}|{{round(m3,3)}}|{{round(qFR3,3)}}|{{round(qFI3,3)}}|{{round(regenEff3,3)}}|
# |{{round(Q6,3)}}|{{round(m6,3)}}|{{round(qFR6,3)}}|{{round(qFI6,3)}}|{{round(regenEff6,3)}}|
# |{{round(Q9,3)}}|{{round(m9,3)}}|{{round(qFR9,3)}}|{{round(qFI9,3)}}|{{round(regenEff9,3)}}|-->

# %% [markdown]
# # Results
# |Flowrate $\dfrac{mL}{min}$|Mass of resin used (g)|Real Capacity $q_{F_R}$|Ideal Capacity $q_{F_I}$|Regeneration Effeciency (%)|
# |---|---|---|---|---|
# |7.567|2.327|3.591|4.0|99.548|
# |8.028|2.54|204.146|212.944|95.869|
# |14.311|2.332|3.678|3.652|100.712|
# |21.228|2.304|3.568|4.161|85.76|

# %% [markdown]
# # Analyzing Results from Day 4

# %% [markdown]
# Importing Data

# %%
m3_2 = 2.3266
Q3_2 = np.mean([(10/80.54),(10/79.05),(10/78.31)])*60
m9_2 = 2.288
Q9_2 = np.mean([(10/27.51),(10/28.65),(10/28.02)])*60

# %%
r5d4f3a = pd.read_csv('01_Text_Files/Run5_FR_3_A.txt',skiprows=7,header=None,sep='\t')
r5d4f3a.columns = ["time","Transmittance","Absorbance"]
r5d4f3a['time_Plot'] = r5d4f3a.time
r5d4f3a_timearray = np.array(r5d4f3a.time_Plot)

r5d4f3b = pd.read_csv('01_Text_Files/Run5_FR_3_B.txt',skiprows=7,header=None,sep='\t')
r5d4f3b.columns = ["time","Transmittance","Absorbance"]
r5d4f3b['time_Plot'] = r5d4f3a_timearray[-1] + r5d4f3b.time
r5d4f3b_timearray = np.array(r5d4f3b.time_Plot)

r5d4f3c = pd.read_csv('01_Text_Files/Run5_FR_3_C.txt',skiprows=7,header=None,sep='\t')
r5d4f3c.columns = ["time","Transmittance","Absorbance"]
r5d4f3c['time_Plot'] = r5d4f3b_timearray[-1] + r5d4f3c.time
r5d4f3c_timearray = np.array(r5d4f3c.time_Plot)

r6d4f9a = pd.read_csv('01_Text_Files/Run6_FR_9_A.txt',skiprows=7,header=None,sep='\t')
r6d4f9a.columns = ["time","Transmittance","Absorbance"]
r6d4f9a['time_Plot'] = r6d4f9a.time
r6d4f9a_timearray = np.array(r6d4f9a.time_Plot)

r6d4f9b = pd.read_csv('01_Text_Files/Run4_FR_6_B.txt',skiprows=7,header=None,sep='\t')
r6d4f9b.columns = ["time","Transmittance","Absorbance"]
r6d4f9b['time_Plot'] = r6d4f9a_timearray[-1] + r6d4f9b.time
r6d4f9b_timearray = np.array(r6d4f9b.time_Plot)

# %%
r5d4f3a['Concentration'] = r5d4f3a.Absorbance/eps
r5d4f3b['Concentration'] = r5d4f3b.Absorbance/eps
r6d4f9a['Concentration'] = r6d4f9a.Absorbance/eps
r6d4f9b['Concentration'] = r6d4f9b.Absorbance/eps
r5d4f3c['Concentration'] = r5d4f3c.Absorbance/eps

# %%
ax = r5d4f3a.plot(x='time_Plot',y='Concentration',label='Before Regeneration')
r5d4f3b.plot(x='time_Plot',y='Concentration',ax=ax,label='After Regeneration')
ax.set_xlabel('time (min)')
ax.set_ylabel('Concentration Copper Sulfate ($\dfrac{mol}{L}$)')
title3_2 = "Concentration vs Time plot for Q = {} mL/min".format(round(Q3_2,3))
ax.set_title(title3_2)

ax2 = r6d4f9a.plot(x='time_Plot',y='Concentration',label='Before Regeneration')
r6d4f9b.plot(x='time_Plot',y='Concentration',ax=ax2,label='After Regeneration')
ax2.set_ylabel('Concentration Copper Sulfate ($\dfrac{mol}{L}$)')
title9_2 = "Concentration vs Time plot for Q = {} mL/min".format(round(Q9_2,3))
ax2.set_title(title9_2)

r5d4f3c.plot(x='time_Plot',y='Concentration',label='????',ax=ax2)

# %% [markdown]
# # Plotting Breakthrough Curves before Regeneration at different flowrates

# %%
FRp3a = r1d2f3a[r1d2f3a.time < 5].copy()
FRp6a = r4d3f6a[r4d3f6a.time < 5].copy()
FRp9a = r3d3f9a[r3d3f9a.time < 5].copy()
FRp3b = r5d4f3a[r5d4f3a.time < 5].copy()

FRpr3a = r2d2f3a[r2d2f3a.time < 3].copy()
FRpr6a = r4d3f6b[r4d3f6b.time < 3].copy()
FRpr9a = r3d3f9b[r3d3f9b.time < 3].copy()
FRpr3b = r5d4f3b[r5d4f3b.time < 3].copy()
ax = FRp3b.plot(x='time',y='Concentration',label='Q = {} mL/min'.format(round(Q3_2,3)))
#FRp3a.plot(x='time',y='Concentration',label = 'Q = {} mL/min'.format(round(Q3,3)),ax=ax)
FRp6a.plot(x='time',y='Concentration',label = 'Q = {} mL/min'.format(round(Q6,3)),ax=ax)
FRp9a.plot(x='time',y='Concentration',label = 'Q = {} mL/min'.format(round(Q9,3)),ax=ax)

ax.set_title('Breakthrough Curves Before Regeneration \n at various Flowrates')
ax.set_ylabel('Concentration (M)')

ax2 = FRpr3b.plot(x='time',y='Concentration',label='Q = {} mL/min'.format(round(Q3_2,3)))
#FRp3a.plot(x='time',y='Concentration',label = 'Q = {} mL/min'.format(round(Q3,3)),ax=ax)
FRpr6a.plot(x='time',y='Concentration',label = 'Q = {} mL/min'.format(round(Q6,3)),ax=ax2)
FRpr9a.plot(x='time',y='Concentration',label = 'Q = {} mL/min'.format(round(Q9,3)),ax=ax2)


ax2.set_title('Breakthrough Curve After Regeneration \n at various Flowrates')
ax2.set_ylabel('Concentration (M)')
# Out:
# Text(0,0.5,'Concentration (M)')

# %%
ideal3_2 = r5d4f3a[(r5d4f3a.time <= 2.5) & (r5d4f3a.time>=2)].copy()
ax = ideal3_2.plot(x='time',y='Concentration',label='Before Regeneration')
regen1_3_2 = r5d4f3b[(r5d4f3b.time<= 2.5) & (r5d4f3b.time>=2)].copy()
regen1_3_2.plot(x='time',y='Concentration',label='After Regeneration',ax=ax)
ax.set_ylabel('Concentration ($\dfrac{mol}{L}$)')
title3_2 = "Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = {} mL/min".format(round(Q3_2,3))
ax.set_title(title3_2)

ideal9_2 = r6d4f9a[(r6d4f9a.time <= 0.8) & (r6d4f9a.time>=0.65)].copy()
ax2 = ideal9_2.plot(x='time',y='Concentration',label='Before Regeneration')
regen1_9_2 = r6d4f9b[(r6d4f9b.time<= 1.4) & (r6d4f9b.time>=1)].copy()
regen1_9_2.plot(x='time',y='Concentration',label='After Regeneration',ax=ax2)
ax2.set_ylabel('Concentration ($\dfrac{mol}{L}$)')
title9_2 = "Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = {} mL/min".format(round(Q9_2,3))
ax2.set_title(title9_2)
# Out:
# Text(0.5,1,'Linear Part of Breakthrough Curve \n Before and After Regeneration \n at Flowrate = 21.389 mL/min')

# %%
# Calculating and Plotting Thomas Model Points
ideal3_2['Thomas'] = np.log((CF/ideal3_2['Concentration'])-1)
regen1_3_2['Thomas'] = np.log((CF/regen1_3_2['Concentration'])-1)
ax = ideal3_2.plot.scatter(x='time',y='Thomas',label='Breakthrough 1',color='C0')
regen1_3_2.plot.scatter(x='time',y='Thomas',label='After Regeneration 1',ax=ax,color='C1')
ax.set_xlabel('time(min)')
ax.set_ylabel('$ln(\dfrac{C_F}{C} -1)$')
title3_2 = "Thomas Model Curve Comparing before and After \n regeneration at Flowrate = {} mL/min".format(round(Q3_2,3))
ax.set_title(title3_2)

ideal9_2['Thomas'] = np.log((CF/ideal9_2['Concentration'])-1)
regen1_9_2['Thomas'] = np.log((CF/regen1_9_2['Concentration'])-1)
ax2 = ideal9_2.plot.scatter(x='time',y='Thomas',label='Breakthrough 1',color='C0')
regen1_9_2.plot.scatter(x='time',y='Thomas',label='After Regeneration 1',ax=ax2,color='C1')
ax2.set_xlabel('time(min)')
ax2.set_ylabel('$ln(\dfrac{C_F}{C} -1)$')
title9_2 = "Thomas Model Curve Comparing before and After \n regeneration at Flowrate = {} mL/min".format(round(Q9_2,3))
ax2.set_title(title9_2)

# Calcualting the linear fit of the thomas model, and plotting it with the calculated Thomas model points.
slopeI3_2, interceptI3_2, r_valueI3_2, p_valueI3_2, std_errI3_2 = stats.linregress(ideal3_2['time'],ideal3_2['Thomas'])
slopeR3_2, interceptR3_2, r_valueR3_2, p_valueR3_2, std_errR3_2 = stats.linregress(regen1_3_2['time'],regen1_3_2['Thomas'])
ideal3_2['ThomasPredict'] = ideal3_2['time']*slopeI3_2 + interceptI3_2
regen1_3_2['ThomasPredict'] = regen1_3_2['time']*slopeR3_2 + interceptR3_2
ideal3_2.plot(x='time',y='ThomasPredict', ax=ax,label='Ideal',color='C0')
regen1_3_2.plot(x='time',y='ThomasPredict', ax=ax,label='Regenerated',color='C1')


slopeI9_2, interceptI9_2, r_valueI9_2, p_valueI9_2, std_errI9_2 = stats.linregress(ideal9_2['time'],ideal9_2['Thomas'])
slopeR9_2, interceptR9_2, r_valueR9_2, p_valueR9_2, std_errR9_2 = stats.linregress(regen1_9_2['time'],regen1_9_2['Thomas'])
ideal9_2['ThomasPredict'] = ideal9_2['time']*slopeI9_2 + interceptI9_2
regen1_9_2['ThomasPredict'] = regen1_9_2['time']*slopeR9_2 + interceptR9_2
#print([ideal3_2regen1_9_2.ThomasPredict])
ideal9_2.plot(x='time',y='ThomasPredict', ax=ax2,label='Ideal',color='C0')
regen1_9_2.plot(x='time',y='ThomasPredict', ax=ax2,label='Regenerated',color='C1')

# %%
kthI3_2 = -slopeI3_2/CF
qFI3_2 = (interceptI3_2 * Q3_2)/(m3_2 * kthI3_2)
kthR3_2 = -slopeR3_2/CF
qFR3_2 = (interceptR3_2 * Q3_2)/(m3_2 * kthR3_2)

kthI9_2 = -slopeI9_2/CF
qFI9_2 = (interceptI9_2 * Q9_2)/(m9_2 * kthI9_2)
kthR9_2 = -slopeR9_2/CF
qFR9_2 = (interceptR9_2 * Q9_2)/(m9_2 * kthR9_2)

regenEff9_2 = (qFR9_2/qFI9_2)*100

kthI6 = -slopeI6/CF
qFI6 = (interceptI6 * Q6)/(m6 * kthI6)
kthR6 = -slopeR6/CF
qFR6 = (interceptR6 * Q6)/(m6 * kthR6)

regenEff6 = (qFR6/qFI6)*100

regenEff3_2 = (qFR3_2/qFI3_2)*100

print("Flowrate = {} mL/min \n Ideal case \n \tkth: {} \n\tqF: {}".format(round(Q3_2,3),round(kthI3_2,3), round(qFI3_2,3)))
print(" After 1 regeneration\n \tkth: {} \n\tqF: {} mol/g resin".format(round(kthR3,3), round(qFR3,3)))
print("Regeneration Efficiency = {}\n\n".format(round(regenEff3_2,3)))

print("Flowrate = {} mL/min \n Ideal case \n \tkth: {} \n\tqF: {}".format(round(Q9_2,3),round(kthI9_2,3), round(qFI9_2,3)))
print(" After 1 regeneration\n \tkth: {} \n\tqF: {} mol/g resin".format(round(kthR9_2,3), round(qFR9_2,3)))
print("Regeneration Efficiency = {}\n\n".format(round(regenEff9_2,3)))

#print("Flowrate = {} mL/min \n Ideal case \n \tkth: {} \n\tqF: {}".format(round(Q9,3),round(kthI9,3), round(qFI9,3)))
#print(" After 1 regeneration\n \tkth: {} \n\tqF: {} mol /g resin".format(round(kthR9,3), round(qFR9,3)))
#print("Regeneration Efficiency = {}\n\n".format(round(regenEff9,3)))
# Out:
# Flowrate = 7.567 mL/min
#  Ideal case
#  	kth: 26.226
# 	qF: 3.607
#  After 1 regeneration
#  	kth: 0.196
# 	qF: 204.146 mol/g resin
# Regeneration Efficiency = 99.578
#
#
# Flowrate = 21.389 mL/min
#  Ideal case
#  	kth: 52.185
# 	qF: 3.584
#  After 1 regeneration
#  	kth: 40.004
# 	qF: 5.619 mol/g resin
# Regeneration Efficiency = 156.774

# %% [markdown]
# <!--# Summarizing Results
# |Flowrate $\dfrac{mL}{min}$|Mass of resin used (g)|Capacity After Regeneration$q_{F_R}$|Capacity Before Regeneration$q_{F_I}$|Regeneration Effeciency (%)|
# |---|---|---|---|---|
# |{{round(Q3_2,3)}}|{{round(m3_2,3)}}|{{round(qFR3_2,3)}}|{{round(qFI3_2,3)}}|{{round(regenEff3_2,3)}}|
# |{{round(Q3,3)}}|{{round(m3,3)}}|{{round(qFR3,3)}}|{{round(qFI3,3)}}|{{round(regenEff3,3)}}|
# |{{round(Q6,3)}}|{{round(m6,3)}}|{{round(qFR6,3)}}|{{round(qFI6,3)}}|{{round(regenEff6,3)}}|
# |{{round(Q9,3)}}|{{round(m9,3)}}|{{round(qFR9,3)}}|{{round(qFI9,3)}}|{{round(regenEff9,3)}}|-->

# %% [markdown]
# # Summarizing Results
# |Flowrate $\dfrac{mL}{min}$|Mass of resin used (g)|Capacity After Regeneration$q_{F_R}$|Capacity Before Regeneration$q_{F_I}$|Regeneration Effeciency (%)|
# |---|---|---|---|---|
# |7.567|2.327|3.591|3.607|99.578|
# |8.028|2.54|204.146|212.944|95.869|
# |14.311|2.332|3.678|3.652|100.712|
# |21.2228|2.304|3.568|4.161|85.76|

# %%
Data = pd.DataFrame({'Flowrate':[round(Q3_2,3),round(Q3,3),round(Q6,3),round(Q9,3)], 'Ideal Capacity':[qFI3_2,qFI3, qFI6,qFI9], 'Real Capacity':[qFR3_2,qFR3, qFR6, qFR9], 'Efficiency':[regenEff3_2, regenEff3,regenEff6, regenEff9]})
ax = Data.plot.bar(x='Flowrate',y='Efficiency',legend=False)
ax.set_xlabel('Flowrate(mL/min)')
ax.set_ylabel('% Efficiency')
ax.set_title('Trend of Efficiency as a function of flowrate')
# Out:
# Text(0.5,1,'Trend of Efficiency as a function of flowrate')

# %% [markdown]
# # Statistical Analysis, Error Propigation and Error Analysis
# ## Standard  deviations around extinction coefficient value
# Justification for using mean from previous groups

# %% [markdown]
# Using the average $ε$ value,$3.348$ to convert absorbance into concentration, for this process is reasionable because the standard deviation, $σ$, is $0.106$, which is less than 10% of the mean value.

# %%
print('Using the average ε, {} for the value to convert absorbance into concentration for this process is reasonable because \nthe standard deviation, σ is {}, which is less than 10% off the mean value'.format(round(eps,3),round(epsstd,3)))
# Out:
# Using the average ε, 3.348 for the value to convert absorbance into concentration for this process is reasonable because
# the standard deviation, σ is 0.106, which is less than 10% off the mean value

# %% [markdown]
# ## Standard Deviations around Flowrates
# For the information taken on day 4, standard deviations were taken on flowrates measured. Standard deviations are not available for previous collection days because only 2 flowrates were measured, and not three. 3 measurements is the minimum number of measurements needed for a meaningful standard deviation.

# %%
FR3_2_list = np.array([(10/80.54),(10/79.05),(10/78.31)])*60
Q3_2σ = np.std(FR3_2_list)
Q3_2μ = np.mean(FR3_2_list)
FR9_2_list = np.array([(10/27.51),(10/28.65),(10/28.02)])*60
Q9_2σ = np.std(FR9_2_list)
Q9_2μ = np.std(FR9_2_list)

# %% [markdown]
# The mean flowrates from day two are {{round(Q3_2,3)}} and {{round(Q9_2,3)}}. Their standard deviations are {{round(Q3_2σ,3)}} and {{round(Q9_2σ,3)}}, respectively. Becuase the standard deviations are so small in comparison to their values, it is valid to say that the flowarte of any given trial is constant.

# %% [markdown]
# # References
#
# (1) Group M1Section 1 Fall. Analysis of Cationic Dowex Ion Exchange Resins Crosslinking Effects on Absorbance. University of Massachusetts, ChemE Department Round 1.
# (2) Kolev, S.; Berns, G.; Flaherty, C. Ion Exchage. Group D1 - We’re Dippin March 6, 2019.
# (3) Group D1 Section 1 Fall. Ion Exchange. University of Massachusetts, ChemE Department Round 2.
# (4) Group D2 Section 2 Fall. Ion Exchange. University of Massachusetts, ChemE Department Round 2.
# (5) Group B2 Section 2 Fall “B2: Spirit.” ION EXCHANGE (ROUND 4) A Study of the Effects of Dowex 50w Resin Mesh Size on Breakthrough Curves and Scale up Possibilities. University of Massachusetts, ChemE Department Round 4.
# (6) Group C1 Section 1 Fall. Ion Exchange Batch Process. University of Massachusetts, ChemE Department September 1, 2018.
# (7) Group C2 Section 2 Fall. Ion Exchange Chromatography. University of Massachusetts, ChemE Department September 1, 2018.
# (8) Burke, E.; Eymontt, E.; Kanellias, S.; Paquin, L. Ion Exchange Round 1. C2 Shining Sea February 19, 2019.
# (9) Group A1 Section 1 Fall “Money Team.” Ion Exchange Round 3 Final REport. University of Massachusetts, ChemE Department Round 3.
# (10) Group A2 Section 2 Fall. Ion Exchange Round 3 Final Report. University of Massachusetts, ChemE Department Round 3.
# (11) Boumghait, S.; Panariello, J.; Colon, A.; Ritchie, P. Ion Exchange: Round 2. The Mighty Ducks: Group D2 March 8, 2019.
# (12) Group B1 Section 1 Fall “Smart Acids.” Ion Exchange: Round 4. University of Massachusetts, ChemE Department Round 4.

# %% [markdown]
# # Raw Data
# Below is a print of all of text files. These are also available as separate text files.

# %%
f = open('01_Text_Files/Run1_FR_3_A.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run1_FR_3_B.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run1_FR_3_C.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run2_FR_3_A.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run3_FR_9_A.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run3_FR_9_B.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run4_FR_6_A.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run4_FR_6_B.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run5_FR_3_A.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run5_FR_3_B.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run5_FR_3_C.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run6_FR_9_A.txt','r');
data = f.read()
print(data)
f.close()
f = open('01_Text_Files/Run6_FR_9_B.txt','r');
data = f.read()
print(data)
f.close()
# Out:
# Vernier Format 2
# Untitled.sbl	14:18  Monday, March 25, 2019
# Latest
# Time	Transmittance	Absorbance
# Time	%Trans	Abs
# min	%
#
# 0.000000000	100.000000000	0.000000000
# 0.016666668	100.000000000	0.000000000
# 0.033333335	100.000000000	0.000000000
# 0.050000004	100.000000000	0.000000000
# 0.066666670	100.000000000	0.000000000
# 0.083333336	100.000000000	0.000000000
# 0.100000009	100.000000000	0.000000000
# 0.116666675	100.000000000	0.000000000
# 0.133333340	100.000000000	0.000000000
# 0.150000006	100.000000000	0.000000000
# 0.166666672	100.000000000	0.000000000
# 0.183333337	100.000000000	0.000000000
# 0.200000018	100.000000000	0.000000000
# 0.216666684	100.000000000	0.000000000
# 0.233333349	100.000000000	0.000000000
# 0.250000000	100.000000000	0.000000000
# 0.266666681	100.000000000	0.000000000
# 0.283333361	100.000000000	0.000000000
# 0.300000012	100.000000000	0.000000000
# 0.316666692	100.000000000	0.000000000
# 0.333333343	100.000000000	0.000000000
# ...
